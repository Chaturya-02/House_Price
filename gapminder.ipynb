# %% [markdown]
# # Task 1 : Import libraries
# # Task 2 : Load dataset
# # Task 3 : Creating Table
# # Task 4 : Quick visualisation with Bar Chart
# # Task 5 : Plot life Expectency vs GDP Per capita
# # Task 6 : Create interactive bubble chart
# # Task 7 : Create interactive Animation and Facet plot
# # Task 8 : Interactive Line Plot and Area Plot
# # Task 9 : Represent Geographic data as animated maps

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline


import plotly.express as px
import plotly.offline as po
# this module provides functionality for generating poltly visualization offline.

po.offline.init_notebook_mode(connected=True)
# this line setup the notebook to diplay plotly visualization directly within the notebook interface

import plotly.graph_objs as go
# This module contains the core component method require to create and customize plotly graphs

from plotly.figure_factory import create_table
#this function generate table
# Out:
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-2.27.0.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>

# %% [markdown]
# Load Dataset

# %%
#load the gapminder dataset from plotly express
gapminder=px.data.gapminder()
gapminder
# Out:
#           country continent  year  lifeExp       pop   gdpPercap iso_alpha  \
# 0     Afghanistan      Asia  1952   28.801   8425333  779.445314       AFG
# 1     Afghanistan      Asia  1957   30.332   9240934  820.853030       AFG
# 2     Afghanistan      Asia  1962   31.997  10267083  853.100710       AFG
# 3     Afghanistan      Asia  1967   34.020  11537966  836.197138       AFG
# 4     Afghanistan      Asia  1972   36.088  13079460  739.981106       AFG
# ...           ...       ...   ...      ...       ...         ...       ...
# 1699     Zimbabwe    Africa  1987   62.351   9216418  706.157306       ZWE
# 1700     Zimbabwe    Africa  1992   60.377  10704340  693.420786       ZWE
# 1701     Zimbabwe    Africa  1997   46.809  11404948  792.449960       ZWE
# 1702     Zimbabwe    Africa  2002   39.989  11926563  672.038623       ZWE
# 1703     Zimbabwe    Africa  2007   43.487  12311143  469.709298       ZWE
#
#       iso_num
# 0           4
# 1           4
# 2           4
# ...

# %%
gapminder.size
# Out:
# 13632

# %%
gapminder.head()
b=gapminder.tail()
print(gapminder.head())
print(b)
# Out:
#        country continent  year  lifeExp       pop   gdpPercap iso_alpha  \
# 0  Afghanistan      Asia  1952   28.801   8425333  779.445314       AFG
# 1  Afghanistan      Asia  1957   30.332   9240934  820.853030       AFG
# 2  Afghanistan      Asia  1962   31.997  10267083  853.100710       AFG
# 3  Afghanistan      Asia  1967   34.020  11537966  836.197138       AFG
# 4  Afghanistan      Asia  1972   36.088  13079460  739.981106       AFG
#
#    iso_num
# 0        4
# 1        4
# 2        4
# 3        4
# 4        4
#        country continent  year  lifeExp       pop   gdpPercap iso_alpha  \
# 1699  Zimbabwe    Africa  1987   62.351   9216418  706.157306       ZWE
# 1700  Zimbabwe    Africa  1992   60.377  10704340  693.420786       ZWE
# 1701  Zimbabwe    Africa  1997   46.809  11404948  792.449960       ZWE
# 1702  Zimbabwe    Africa  2002   39.989  11926563  672.038623       ZWE
# 1703  Zimbabwe    Africa  2007   43.487  12311143  469.709298       ZWE
#
#       iso_num
# ...

# %%
gapminder.columns
# Out:
# Index(['country', 'continent', 'year', 'lifeExp', 'pop', 'gdpPercap',
#        'iso_alpha', 'iso_num'],
#       dtype='object')

# %%
gapminder['country'].value_counts()
# Out:
# country
# Afghanistan          12
# Pakistan             12
# New Zealand          12
# Nicaragua            12
# Niger                12
#                      ..
# Eritrea              12
# Equatorial Guinea    12
# El Salvador          12
# Egypt                12
# Zimbabwe             12
# Name: count, Length: 142, dtype: int64

# %%
gapminder['continent'].value_counts()
# Out:
# continent
# Africa      624
# Asia        396
# Europe      360
# Americas    300
# Oceania      24
# Name: count, dtype: int64

# %%
gapminder['year'].value_counts()
# Out:
# year
# 1952    142
# 1957    142
# 1962    142
# 1967    142
# 1972    142
# 1977    142
# 1982    142
# 1987    142
# 1992    142
# 1997    142
# 2002    142
# 2007    142
# Name: count, dtype: int64

# %%
gapminder['lifeExp'].value_counts()
# Out:
# lifeExp
# 69.390    4
# 66.800    3
# 78.770    3
# 70.750    3
# 76.420    3
#          ..
# 55.861    1
# 52.644    1
# 49.265    1
# 45.580    1
# 43.487    1
# Name: count, Length: 1626, dtype: int64

# %%
d=create_table(gapminder.describe())
fig=go.Figure(data=d)
fig.show()

# %% [markdown]
# canada_Data

# %%
canada_data = px.data.gapminder().query("country=='Canada'")

#create bar charts
fig=px.bar(canada_data,x='year',y='pop',height=500)
fig.show()

# %%
india_data = px.data.gapminder().query("country=='India'")

#create bar charts
fig=px.bar(india_data,x='year',y='pop',height=400)
fig.show()

# %%
#lets add the color lifeExp
fig=px.bar(india_data,x='year',y='pop',color='lifeExp', labels={'pop':'Popualtion of India'},height=400)
fig.show()

# %%
#fiter 2007 data only from dataset
gapminder2007 = gapminder.query('year == 2007')
# create scatter plot
fig=px.scatter(gapminder2007, x='gdpPercap',y='lifeExp',color='continent',size='pop', size_max=60)
fig.show()

# %% [markdown]
# ## Create Interactive Animation and Facetplots

# %%
gapminder2007 = gapminder.query('year == 2007')

fig=px.scatter(gapminder2007, x='gdpPercap',y='lifeExp',color='continent',
               size='pop', size_max=60, hover_name='country', facet_col='continent' )
fig.show()

# %%
gapminder2007 = gapminder.query('year == 2007')

fig=px.scatter(gapminder2007, x='gdpPercap',y='lifeExp',color='continent',
               size='pop', size_max=60, hover_name='country', facet_col='continent',log_x=True )
fig.show()

# %%
fig=px.scatter(gapminder, x='gdpPercap',y='lifeExp',color='continent',
               size='pop', size_max=60, hover_name='country',log_x=True, animation_frame='year',
                animation_group='country', range_x=[25,10000],range_y=[25,90] )
fig.show()

# %%
fig=px.scatter(gapminder, x='gdpPercap',y='lifeExp',color='continent',
               size='pop', size_max=60, hover_name='country',log_x=True, animation_frame='year',
                animation_group='country', range_x=[25,10000],range_y=[25,90],
               labels=dict(pop="population",gdpPercap="GDP Per Capita", lifeExp="Life Expectency"))
fig.show()

# %% [markdown]
# ## Represent Geographic Data as Animation

# %%
# Create map suing choropleth
fig=px.choropleth(gapminder, locations='iso_alpha',color='lifeExp',
                  hover_name='country',animation_frame='year',
                  color_continuous_scale=px.colors.sequential.Plasma,
                  projection='natural earth')
fig.show()
# Out:
# <div>                            <div id="f9614eda-b079-43be-8bc6-339e6f161729" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("f9614eda-b079-43be-8bc6-339e6f161729")) {                    Plotly.newPlot(                        "f9614eda-b079-43be-8bc6-339e6f161729",                        [{"coloraxis":"coloraxis","geo":"geo","hovertemplate":"\u003cb\u003e%{hovertext}\u003c\u002fb\u003e\u003cbr\u003e\u003cbr\u003eyear=1952\u003cbr\u003eiso_alpha=%{location}\u003cbr\u003elifeExp=%{z}\u003cextra\u003e\u003c\u002fextra\u003e","hovertext":["Afghanistan","Albania","Algeria","Angola","Argentina","Australia","Austria","Bahrain","Bangladesh","Belgium","Benin","Bolivia","Bosnia and Herzegovina","Botswana","Brazil","Bulgaria","Burkina Faso","Burundi","Cambod
# ...
